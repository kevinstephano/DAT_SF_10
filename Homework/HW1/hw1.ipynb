# %%
import json,datetime,sqlite3,os

if __name__ == "__main__" :
  json_data = open( "ga_hw_logins.json" )
  login_data = json.load( json_data )

  datetime_object_list = []

  for entry in login_data:
    datetime_object_list.append( datetime.datetime.strptime( entry, "%Y-%m-%d %H:%M:%S" ) )
    
  # I am cheating and deleting the db each time, if necessary
  if os.path.exists('login.db') :
    os.remove('login.db')

  conn = sqlite3.connect('login.db')

  conn.execute('''CREATE TABLE logins (date text, hour real)''')

  for obj in datetime_object_list:
    insert_str = "INSERT INTO logins VALUES ('" + obj.date().__str__() + "'," + str(obj.time().hour) + ")"
    conn.execute( insert_str )

  conn.commit()

  # Grouping by date,hour and counting up those groups.
  # Largest date/hour is on top
  cursor = conn.execute( "SELECT date,hour,COUNT(hour) FROM logins GROUP BY date,hour ORDER BY COUNT(hour) DESC" )
  for row in cursor:
    print row

  conn.close()
# Out:
# (u'2014-01-22', 2.0, 54)
# (u'2014-01-22', 21.0, 51)
# (u'2014-01-22', 1.0, 50)
# (u'2014-01-22', 3.0, 48)
# (u'2014-01-23', 2.0, 48)
# (u'2014-01-23', 0.0, 47)
# (u'2014-01-23', 1.0, 45)
# (u'2014-01-21', 22.0, 44)
# (u'2014-01-23', 3.0, 42)
# (u'2014-01-22', 20.0, 40)
# (u'2014-01-22', 23.0, 40)
# (u'2014-01-21', 21.0, 39)
# (u'2014-01-21', 20.0, 34)
# (u'2014-01-22', 4.0, 33)
# (u'2014-01-21', 23.0, 32)
# (u'2014-01-23', 4.0, 30)
# (u'2014-01-21', 1.0, 28)
# (u'2014-01-26', 22.0, 28)
# (u'2014-01-26', 23.0, 27)
# (u'2014-01-22', 0.0, 26)
# (u'2014-01-23', 5.0, 26)
# (u'2014-01-20', 0.0, 25)
# (u'2014-01-20', 23.0, 25)
# (u'2014-01-22', 22.0, 25)
# (u'2014-01-20', 1.0, 24)
# (u'2014-01-25', 22.0, 24)
# (u'2014-01-24', 23.0, 23)
# (u'2014-01-26', 0.0, 23)
# (u'2014-01-26', 21.0, 23)
# (u'2014-01-25', 21.0, 22)
# (u'2014-01-21', 0.0, 21)
# (u'2014-01-20', 20.0, 20)
# (u'2014-01-21', 2.0, 20)
# (u'2014-01-22', 19.0, 20)
# (u'2014-01-23', 13.0, 20)
# (u'2014-01-25', 0.0, 20)
# (u'2014-01-25', 1.0, 19)
# (u'2014-01-20', 22.0, 18)
# (u'2014-01-22', 18.0, 18)
# (u'2014-01-23', 20.0, 18)
# (u'2014-01-23', 21.0, 18)
# (u'2014-01-25', 20.0, 18)
# (u'2014-01-24', 21.0, 16)
# (u'2014-01-20', 16.0, 15)
# (u'2014-01-21', 3.0, 15)
# (u'2014-01-22', 14.0, 15)
# (u'2014-01-22', 15.0, 15)
# (u'2014-01-22', 17.0, 15)
# (u'2014-01-23', 18.0, 15)
# (u'2014-01-23', 19.0, 14)
# (u'2014-01-24', 10.0, 14)
# (u'2014-01-20', 19.0, 13)
# (u'2014-01-22', 16.0, 13)
# (u'2014-01-23', 15.0, 13)
# (u'2014-01-24', 22.0, 13)
# (u'2014-01-25', 19.0, 13)
# (u'2014-01-26', 10.0, 13)
# (u'2014-01-26', 20.0, 13)
# (u'2014-01-21', 11.0, 12)
# (u'2014-01-21', 14.0, 12)
# (u'2014-01-21', 17.0, 12)
# (u'2014-01-22', 12.0, 12)
# (u'2014-01-23', 6.0, 12)
# (u'2014-01-23', 14.0, 12)
# (u'2014-01-23', 22.0, 12)
# (u'2014-01-24', 12.0, 12)
# (u'2014-01-24', 18.0, 12)
# (u'2014-01-24', 20.0, 12)
# (u'2014-01-26', 1.0, 12)
# (u'2014-01-26', 9.0, 12)
# (u'2014-01-26', 15.0, 12)
# (u'2014-01-20', 12.0, 11)
# (u'2014-01-21', 4.0, 11)
# (u'2014-01-22', 5.0, 11)
# (u'2014-01-23', 7.0, 11)
# (u'2014-01-23', 23.0, 11)
# (u'2014-01-24', 0.0, 11)
# (u'2014-01-24', 1.0, 11)
# (u'2014-01-25', 16.0, 11)
# (u'2014-01-25', 18.0, 11)
# (u'2014-01-26', 2.0, 11)
# (u'2014-01-26', 13.0, 11)
# (u'2014-01-26', 18.0, 11)
# (u'2014-01-20', 3.0, 10)
# (u'2014-01-20', 21.0, 10)
# (u'2014-01-21', 10.0, 10)
# (u'2014-01-21', 16.0, 10)
# (u'2014-01-21', 18.0, 10)
# (u'2014-01-23', 12.0, 10)
# (u'2014-01-23', 17.0, 10)
# (u'2014-01-24', 11.0, 10)
# (u'2014-01-24', 19.0, 10)
# (u'2014-01-26', 12.0, 10)
# (u'2014-01-21', 19.0, 9)
# (u'2014-01-24', 13.0, 9)
# (u'2014-01-24', 15.0, 9)
# (u'2014-01-24', 16.0, 9)
# (u'2014-01-25', 17.0, 9)
# (u'2014-01-26', 11.0, 9)
# (u'2014-01-20', 10.0, 8)
# (u'2014-01-21', 12.0, 8)
# (u'2014-01-22', 13.0, 8)
# (u'2014-01-24', 17.0, 8)
# (u'2014-01-25', 3.0, 8)
# (u'2014-01-25', 12.0, 8)
# (u'2014-01-26', 14.0, 8)
# (u'2014-01-20', 2.0, 7)
# (u'2014-01-20', 8.0, 7)
# (u'2014-01-20', 11.0, 7)
# (u'2014-01-20', 14.0, 7)
# (u'2014-01-21', 8.0, 7)
# (u'2014-01-21', 9.0, 7)
# (u'2014-01-22', 6.0, 7)
# (u'2014-01-23', 11.0, 7)
# (u'2014-01-24', 3.0, 7)
# (u'2014-01-25', 10.0, 7)
# (u'2014-01-25', 13.0, 7)
# (u'2014-01-25', 23.0, 7)
# (u'2014-01-26', 19.0, 7)
# (u'2014-01-20', 9.0, 6)
# (u'2014-01-20', 13.0, 6)
# (u'2014-01-20', 15.0, 6)
# (u'2014-01-20', 17.0, 6)
# (u'2014-01-20', 18.0, 6)
# (u'2014-01-21', 13.0, 6)
# (u'2014-01-21', 15.0, 6)
# (u'2014-01-22', 9.0, 6)
# (u'2014-01-22', 11.0, 6)
# (u'2014-01-24', 14.0, 6)
# (u'2014-01-25', 2.0, 6)
# (u'2014-01-25', 9.0, 6)
# (u'2014-01-25', 11.0, 6)
# (u'2014-01-25', 14.0, 6)
# (u'2014-01-26', 3.0, 6)
# (u'2014-01-26', 16.0, 6)
# (u'2014-01-26', 17.0, 6)
# (u'2014-01-21', 6.0, 5)
# (u'2014-01-22', 7.0, 5)
# (u'2014-01-22', 10.0, 5)
# (u'2014-01-23', 9.0, 5)
# (u'2014-01-23', 16.0, 5)
# (u'2014-01-24', 2.0, 5)
# (u'2014-01-24', 7.0, 5)
# (u'2014-01-24', 8.0, 5)
# (u'2014-01-24', 9.0, 5)
# (u'2014-01-20', 7.0, 4)
# (u'2014-01-26', 5.0, 4)
# (u'2014-01-20', 4.0, 3)
# (u'2014-01-25', 7.0, 3)
# (u'2014-01-25', 8.0, 3)
# (u'2014-01-25', 15.0, 3)
# (u'2014-01-26', 4.0, 3)
# (u'2014-01-20', 6.0, 2)
# (u'2014-01-21', 5.0, 2)
# (u'2014-01-23', 8.0, 2)
# (u'2014-01-23', 10.0, 2)
# (u'2014-01-24', 5.0, 2)
# (u'2014-01-25', 4.0, 2)
# (u'2014-01-25', 5.0, 2)
# (u'2014-01-25', 6.0, 2)
# (u'2014-01-26', 6.0, 2)
# (u'2014-01-26', 7.0, 2)
# (u'2014-01-26', 8.0, 2)
# (u'2014-01-20', 5.0, 1)
# (u'2014-01-21', 7.0, 1)
# (u'2014-01-22', 8.0, 1)
# (u'2014-01-24', 4.0, 1)
# (u'2014-01-24', 6.0, 1)

# %% [markdown]
# #
